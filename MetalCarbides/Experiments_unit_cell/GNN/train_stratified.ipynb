# %%
import torch 
from torch_geometric.loader import DataLoader
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, max_error
from scipy.stats import pearsonr
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd 
from tqdm import tqdm
from dataset import *
from model import *
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import plotly.express as px
from math import sqrt
import warnings
warnings.filterwarnings("ignore")
device = torch.device("cpu")

# %%
torch_geometric.seed_everything(23)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
data = MoC_c_dir(root ='../Data/coords_direction', max_d = 3.2, max_n = 26)
print("Dataset type: ", type(data))
print("Dataset node features: ", data.num_features)
print("Dataset target: ", data.num_classes)
print("Dataset length: ", data.len)
print("Dataset sample: ", data[0])
print("Sample  nodes: ", data[0].num_nodes)
print("Sample  edges: ", data[0].num_edges)
# Out:
# Dataset type:  <class 'dataset.MoC_c_dir'>
# Dataset node features:  5
# Dataset target:  197
# Dataset length:  <bound method MoC_c_dir.len of MoC_c_dir(200)>
# Dataset sample:  Data(x=[48, 5], edge_index=[2, 414], edge_attr=[414, 6], y=[1, 1])
# Sample  nodes:  48
# Sample  edges:  414

# %%
plt.plot(figsize =(12, 8))
plt.hist([torch.squeeze(data[i].y) for i in range(len(data))], bins = 7, color = 'blue', edgecolor='white')
plt.xlabel('Energy values', fontweight ='bold', fontsize = 12)
plt.ylabel('Frequency', fontweight ='bold', fontsize = 12)
plt.show()

# %%
x = [data[i].x.numpy() for i in range(data.len())]
x = np.array(x)
y = [data[i].y.numpy() for i in range(data.len())]
y = np.array(y)
y = np.squeeze(y, axis = 2)

# %%
limits = np.linspace(np.min(y), np.max(y), num=8)
y_cat = [0]*len(y)
y_cat = np.expand_dims(y_cat, axis = 1)
y_cat = np.array(y_cat)

# %%
y_cat[np.where((y >= limits[0]) & (y <limits[1]))[0]] = 0
y_cat[np.where((y >= limits[1]) & (y <limits[2]))[0]] = 1
y_cat[np.where((y >= limits[2]) & (y <limits[3]))[0]] = 2
y_cat[np.where((y >= limits[3]) & (y <limits[4]))[0]] = 3
y_cat[np.where((y >= limits[4]) & (y <limits[5]))[0]] = 4
y_cat[np.where((y >= limits[5]) & (y <limits[6]))[0]] = 5
y_cat[np.where((y >= limits[6]) & (y <= limits[7]))[0]] = 6
y_cat = y_cat.astype(int)

# %%
folds = StratifiedKFold(n_splits=5, shuffle=False)
train_idx = []
test_idx = []

for i, (train, test) in enumerate(folds.split(x, y_cat)):
    train_idx.append(train)
    test_idx.append(test)

# %%
model = GCN_loop(data.num_features, embedding_size = 64, gnn_layers = 1, improved=False)
print(model)
print(model.forward)
print("Number of parameters: ", count_parameters(model))
# Out:
# GCN_loop(
#   (initial_conv): GCNConv(5, 64)
#   (conv_layers): ModuleList()
#   (out): Linear(in_features=128, out_features=1, bias=True)
# )
# <bound method GCN_loop.forward of GCN_loop(
#   (initial_conv): GCNConv(5, 64)
#   (conv_layers): ModuleList()
#   (out): Linear(in_features=128, out_features=1, bias=True)
# )>
# Number of parameters:  513

# %%
loss_fn = torch.nn.MSELoss()
optimiser = torch.optim.Adam(model.parameters(), lr = 0.001)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimiser, gamma = 1)

# %%
kfold_idx = 2

# %%
train_loader = DataLoader(data[train_idx[kfold_idx]], batch_size = 20, shuffle = True) 
test_loader = DataLoader(data[test_idx[kfold_idx]], batch_size = 10, shuffle = False)

# %%
test_idx[kfold_idx]
# Out:
# array([ 67,  70,  74,  76,  79,  81,  82,  84,  86,  87,  88,  89,  90,
#         92,  94,  95,  97,  98,  99, 100, 101, 102, 104, 105, 106, 107,
#        108, 111, 112, 113, 114, 116, 117, 118, 119, 120, 121, 125, 131,
#        144])

# %%
train_y = [data[train_idx[kfold_idx]][i].y for i in range(len(data[train_idx[kfold_idx]]))]
test_y = [data[test_idx[kfold_idx]][i].y for i in range(len(data[test_idx[kfold_idx]]))]

print(f'The minimum training value is: {min(train_y)}, and the maximum is {max(train_y)}')
print(f'The minimum test value is: {min(test_y)}, and the maximum is {max(test_y)}')
# Out:
# The minimum training value is: tensor([[2.1925]]), and the maximum is tensor([[4.5407]])
# The minimum test value is: tensor([[2.1520]]), and the maximum is tensor([[4.2369]])

# %%
plt.plot(figsize = (12,8))
plt.hist(y[train_idx[kfold_idx]], 7, color = 'blue', label='Train set', edgecolor='white')
plt.hist(y[test_idx[kfold_idx]], 7, color = 'darkorange', label='Test set', edgecolor='black')
plt.xlabel('Energy values', fontweight ='bold', fontsize = 12)
plt.ylabel('Frequency', fontweight ='bold', fontsize = 12)
plt.legend()
plt.show()

# %%
def train(epoch):

    all_preds = []
    all_y = []
    total_loss = 0
    step = 0

    for batch in train_loader:

        # Use GPU
        batch.to(device)

        # Reset gradients
        optimiser.zero_grad()

        # Passing the node features and the connection info
        pred = model(batch.x.float(),  
                        batch.edge_index,
                        batch.batch)
        
        # Calculating the loss and gradients
        loss = torch.sqrt(loss_fn(pred, batch.y))
        loss.backward()

        # Update using the gradients
        optimiser.step() 

        total_loss += loss.item()
        step += 1

        all_preds.append(pred.cpu().detach().numpy())
        all_y.append(batch.y.cpu().detach().numpy())
    
    all_preds = np.concatenate(all_preds).ravel()
    all_labels = np.concatenate (all_y).ravel() 


    return torch.tensor(total_loss/step), all_preds, all_labels

# %%
def test (epoch):
    
    all_preds = []
    all_labels = []
    total_loss = 0
    step = 0

    for batch in test_loader:

        batch.to(device)
        pred = model(batch.x.float(),  
                        batch.edge_index, 
                        batch.batch)
        
        loss = torch.sqrt(loss_fn(pred, batch.y))

        total_loss += loss.item()
        step += 1

        all_preds.append(pred.cpu().detach().numpy())
        all_labels.append(batch.y.cpu().detach().numpy())

    all_preds = np.concatenate(all_preds).ravel()
    all_labels = np.concatenate(all_labels).ravel()

    return torch.tensor(total_loss/step), all_preds, all_labels

# %%
loss_train = []
loss_test = []

pred_train = []
pred_test = []

labels_train = []
labels_test = []

epochs = 501

for epoch in range (epochs):
            # Training
            model.train()
            loss, pred, label = train(epoch=epoch)
            loss = loss.detach().cpu().numpy()

            if epoch % 5 == 0:
                loss_train.append(loss) 

            if epoch % 100 == 0:
                   print(f"Epoch {epoch} | Train Loss {loss}")
                   pred_train.append(pred)
                   labels_train.append(label)

            # Testing
            model.eval()
            if epoch % 5 == 0:
                loss, pred, label = test(epoch=epoch)
                loss = loss.detach().cpu().numpy() 

                if epoch % 10 == 0:
                    loss_test.append(loss)

                if epoch % 100 == 0:
                    print(f"Epoch {epoch} | Test Loss {loss}")
                    pred_test.append(pred)
                    labels_test.append(label)

            scheduler.step()
# Out:
# Epoch 0 | Train Loss 3.0059337615966797
# Epoch 0 | Test Loss 2.564500331878662
# Epoch 100 | Train Loss 0.4670947194099426
# Epoch 100 | Test Loss 0.47994694113731384
# Epoch 200 | Train Loss 0.44051021337509155
# Epoch 200 | Test Loss 0.4660702049732208
# Epoch 300 | Train Loss 0.40414130687713623
# Epoch 300 | Test Loss 0.4542238414287567
# Epoch 400 | Train Loss 0.37938764691352844
# Epoch 400 | Test Loss 0.4445524215698242
# Epoch 500 | Train Loss 0.3682987689971924
# Epoch 500 | Test Loss 0.4331738352775574

# %%
n=2
plt.plot(range(0,epochs,5)[n:], loss_train[n:], 'o-', label = 'Train', color = 'blue')
plt.plot(range(0,epochs,10)[n:], loss_test[n:], 'o-', label = 'Test', color = 'darkorange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
e = 5

plt.scatter(labels_train[e], pred_train[e], color = 'blue', label = 'Train')
plt.scatter(labels_test[e], pred_test[e], color = 'darkorange', label = 'Test')
plt.xlabel("Calculated Energy (DFT) / eV")
plt.ylabel("Predicted Energy / eV")
plt.legend()

plt.text(2.1, 3.5, f'R2: {pearsonr(labels_train[e], pred_train[e])[0]**2:.2f} \n\
MAE: {mean_absolute_error(labels_train[e], pred_train[e]):.2f} \n\
RMSE: {sqrt(mean_squared_error(labels_train[e], pred_train[e])):.2f}', color = 'b')

plt.text(4.25, 2.9, f'R2:  {pearsonr(labels_test[e], pred_test[e])[0]**2:.2f}\n\
MAE: {mean_absolute_error(labels_test[e], pred_test[e]):.2f} \n\
RMSE: {sqrt(mean_squared_error(labels_test[e], pred_test[e])):.2f}', color = 'darkorange')
plt.show()

# %%
def train_folds(kfold, epoch, model, optimiser, loader):

    all_preds = []
    all_y = []
    total_loss = 0
    step = 0

    for batch in loader:

        # Use GPU
        batch.to(device)

        # Reset gradients
        optimiser.zero_grad()

        # Passing the node features and the connection info
        pred = model(batch.x.float(),  
                        batch.edge_index,
                        batch.batch)
        
        # Calculating the loss and gradients
        loss = torch.sqrt(loss_fn(pred, batch.y))
        loss.backward()

        # Update using the gradients
        optimiser.step() 

        total_loss += loss.item()
        step += 1

        all_preds.append(pred.cpu().detach().numpy())
        all_y.append(batch.y.cpu().detach().numpy())
    
    all_preds = np.concatenate(all_preds).ravel()
    all_labels = np.concatenate (all_y).ravel() 
    
    return torch.tensor(total_loss/step), all_preds, all_labels

# %%
def test_folds(kfold, epoch, model, loader):
    
    all_preds = []
    all_labels = []
    total_loss = 0
    step = 0

    for batch in loader:

        batch.to(device)
        pred = model(batch.x.float(),  
                        batch.edge_index, 
                        batch.batch)
        
        loss = torch.sqrt(loss_fn(pred, batch.y)) 

        total_loss += loss.item()
        step += 1

        all_preds.append(pred.cpu().detach().numpy())
        all_labels.append(batch.y.cpu().detach().numpy())

    all_preds = np.concatenate(all_preds).ravel()
    all_labels = np.concatenate(all_labels).ravel()

    return torch.tensor(total_loss/step), all_preds, all_labels

# %%
epochs = 701

#folds x times loss is saved
loss_train_folds = np.zeros((len(train_idx), len(range(0, epochs,  5))))
loss_test_folds = np.zeros((len(train_idx), len(range(0, epochs,  10))))

#times preds are saved x number of predictions x folds
pred_train_folds = np.zeros((len(range(0, epochs, 100)), len(train_idx[0]), len(train_idx)))
pred_test_folds = np.zeros((len(range(0, epochs, 100)), len(test_idx[0]), len(train_idx)))

#times lables are saved x number of predictions x folds
labels_train_folds = np.zeros((len(range(0, epochs, 100)), len(train_idx[0]), len(train_idx)))
labels_test_folds = np.zeros((len(range(0, epochs, 100)), len(test_idx[0]), len(train_idx)))

# %%
loss_fn = torch.nn.MSELoss()
for fold in range(len(train_idx)):

    model = GCN_loop(data.num_features, embedding_size = 64, gnn_layers = 3, improved=False)
    loss_fn = torch.nn.MSELoss()
    optimiser = torch.optim.Adam(model.parameters(), lr = 0.01)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimiser, gamma = 0.995)
    train_loader = DataLoader(data[train_idx[fold]], batch_size = 20, shuffle = True) 
    test_loader = DataLoader(data[test_idx[fold]], batch_size = 10, shuffle = False) 


    for epoch in range (epochs):

        # Training
        model.train()
        loss, pred, label = train_folds(kfold = fold, 
                                        epoch=epoch, 
                                        model = model, 
                                        optimiser = optimiser, 
                                        loader = train_loader)
        
        loss = loss.detach().cpu().numpy()

        if epoch % 5 == 0:
            loss_train_folds[fold, int(epoch / 5)] = loss

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Fold {fold} | Train Loss {loss}")
            pred_train_folds[int(epoch/100), :, fold] = pred
            labels_train_folds[int(epoch/100), :, fold] = label


        # Testing
        model.eval()

        if epoch % 5 == 0:
            loss, pred, label = test_folds(kfold = fold, 
                                           epoch=epoch, 
                                           model=model,
                                           loader = test_loader)
            loss = loss.detach().cpu().numpy() 

            if epoch % 10 == 0:
                loss_test_folds[fold, int(epoch / 10)] = loss

            if epoch % 100 == 0:
                print(f"Epoch {epoch} | Fold {fold} | Test Loss {loss}")
                pred_test_folds[int(epoch/100), :, fold] = pred
                labels_test_folds[int(epoch/100), :, fold] = label
        
        scheduler.step()
    
    print(f'Donde for fold {fold}')
# Out:
# Epoch 0 | Fold 0 | Train Loss 1.0426081418991089
# Epoch 0 | Fold 0 | Test Loss 0.5544639825820923
# Epoch 100 | Fold 0 | Train Loss 0.457540899515152
# Epoch 100 | Fold 0 | Test Loss 0.47475287318229675
# Epoch 200 | Fold 0 | Train Loss 0.25286442041397095
# Epoch 200 | Fold 0 | Test Loss 0.327502578496933
# Epoch 300 | Fold 0 | Train Loss 0.1747101992368698
# Epoch 300 | Fold 0 | Test Loss 0.31378331780433655
# Epoch 400 | Fold 0 | Train Loss 0.12426112592220306
# Epoch 400 | Fold 0 | Test Loss 0.3232533931732178
# Epoch 500 | Fold 0 | Train Loss 0.08659926801919937
# Epoch 500 | Fold 0 | Test Loss 0.3251432180404663
# Epoch 600 | Fold 0 | Train Loss 0.08193556219339371
# Epoch 600 | Fold 0 | Test Loss 0.32945725321769714
# Epoch 700 | Fold 0 | Train Loss 0.06217736005783081
# Epoch 700 | Fold 0 | Test Loss 0.33103784918785095
# Donde for fold 0
# Epoch 0 | Fold 1 | Train Loss 1.0466325283050537
# Epoch 0 | Fold 1 | Test Loss 0.4750877916812897
# Epoch 100 | Fold 1 | Train Loss 0.4515949487686157
# Epoch 100 | Fold 1 | Test Loss 0.43195071816444397
# Epoch 200 | Fold 1 | Train Loss 0.19773544371128082
# Epoch 200 | Fold 1 | Test Loss 0.34395119547843933
# Epoch 300 | Fold 1 | Train Loss 0.13884522020816803
# Epoch 300 | Fold 1 | Test Loss 0.41192421317100525
# Epoch 400 | Fold 1 | Train Loss 0.08544240146875381
# Epoch 400 | Fold 1 | Test Loss 0.4083547592163086
# Epoch 500 | Fold 1 | Train Loss 0.07258355617523193
# Epoch 500 | Fold 1 | Test Loss 0.43836280703544617
# Epoch 600 | Fold 1 | Train Loss 0.04126395285129547
# Epoch 600 | Fold 1 | Test Loss 0.43690335750579834
# Epoch 700 | Fold 1 | Train Loss 0.034799911081790924
# Epoch 700 | Fold 1 | Test Loss 0.4459306299686432
# Donde for fold 1
# Epoch 0 | Fold 2 | Train Loss 1.0062165260314941
# Epoch 0 | Fold 2 | Test Loss 0.4836956858634949
# Epoch 100 | Fold 2 | Train Loss 0.4026321768760681
# Epoch 100 | Fold 2 | Test Loss 0.4888526499271393
# Epoch 200 | Fold 2 | Train Loss 0.2338416427373886
# Epoch 200 | Fold 2 | Test Loss 0.4041837751865387
# Epoch 300 | Fold 2 | Train Loss 0.1425459384918213
# Epoch 300 | Fold 2 | Test Loss 0.36476925015449524
# Epoch 400 | Fold 2 | Train Loss 0.12857036292552948
# Epoch 400 | Fold 2 | Test Loss 0.3676060140132904
# Epoch 500 | Fold 2 | Train Loss 0.07504449039697647
# Epoch 500 | Fold 2 | Test Loss 0.3560391962528229
# Epoch 600 | Fold 2 | Train Loss 0.05374118685722351
# Epoch 600 | Fold 2 | Test Loss 0.35605165362358093
# Epoch 700 | Fold 2 | Train Loss 0.04355128854513168
# Epoch 700 | Fold 2 | Test Loss 0.3556807041168213
# Donde for fold 2
# Epoch 0 | Fold 3 | Train Loss 1.044374704360962
# Epoch 0 | Fold 3 | Test Loss 0.511364221572876
# Epoch 100 | Fold 3 | Train Loss 0.4965765178203583
# Epoch 100 | Fold 3 | Test Loss 0.545756459236145
# Epoch 200 | Fold 3 | Train Loss 0.36391669511795044
# Epoch 200 | Fold 3 | Test Loss 0.4108550250530243
# Epoch 300 | Fold 3 | Train Loss 0.235558420419693
# Epoch 300 | Fold 3 | Test Loss 0.33797839283943176
# Epoch 400 | Fold 3 | Train Loss 0.16711336374282837
# Epoch 400 | Fold 3 | Test Loss 0.33366596698760986
# Epoch 500 | Fold 3 | Train Loss 0.1070886105298996
# Epoch 500 | Fold 3 | Test Loss 0.30430784821510315
# Epoch 600 | Fold 3 | Train Loss 0.08363045752048492
# Epoch 600 | Fold 3 | Test Loss 0.29495570063591003
# Epoch 700 | Fold 3 | Train Loss 0.06922124326229095
# Epoch 700 | Fold 3 | Test Loss 0.29372483491897583
# Donde for fold 3
# Epoch 0 | Fold 4 | Train Loss 0.9788352847099304
# Epoch 0 | Fold 4 | Test Loss 0.49886244535446167
# Epoch 100 | Fold 4 | Train Loss 0.47022926807403564
# Epoch 100 | Fold 4 | Test Loss 0.41588377952575684
# Epoch 200 | Fold 4 | Train Loss 0.33722639083862305
# Epoch 200 | Fold 4 | Test Loss 0.36270466446876526
# Epoch 300 | Fold 4 | Train Loss 0.1916903704404831
# Epoch 300 | Fold 4 | Test Loss 0.3060976564884186
# Epoch 400 | Fold 4 | Train Loss 0.13881920278072357
# Epoch 400 | Fold 4 | Test Loss 0.32961755990982056
# Epoch 500 | Fold 4 | Train Loss 0.1064397394657135
# Epoch 500 | Fold 4 | Test Loss 0.32520467042922974
# Epoch 600 | Fold 4 | Train Loss 0.08655937761068344
# Epoch 600 | Fold 4 | Test Loss 0.33176013827323914
# Epoch 700 | Fold 4 | Train Loss 0.07923668622970581
# Epoch 700 | Fold 4 | Test Loss 0.3439508080482483
# Donde for fold 4

# %%
n=1
fold = 4

plt.plot(figsize =(6, 4))
plt.plot(range(0,epochs,5)[n:], loss_train_folds[fold, n:], 'o-', label = 'Train', color = 'blue')
plt.plot(range(0,epochs,10)[n:], loss_test_folds[fold, n:], 'o-', label = 'Test', color = 'darkorange')
plt.xlabel('Epochs', fontweight ='bold', fontsize = 12)
plt.ylabel('Loss', fontweight ='bold', fontsize = 12)
plt.legend()
plt.show()

# %%
e = 4
fold = 0


plt.plot(figsize =(6, 4))

plt.scatter(labels_train_folds[e,:,fold], pred_train_folds[e,:,fold], color = 'blue', label = 'Train')
plt.scatter(labels_test_folds[e,:,fold], pred_test_folds[e,:,fold], color = 'darkorange', label = 'Test')
plt.xlabel("Calculated Energy (DFT) / eV", fontweight ='bold', fontsize = 12)
plt.ylabel("Predicted Energy / eV", fontweight ='bold', fontsize = 12)
plt.legend()

plt.plot( [2.25, 4],[2.25, 4], color = 'orangered' )

plt.text(2.1, 3.5, f'$R^2$: {pearsonr(labels_train_folds[e,:,fold],pred_train_folds[e,:,fold])[0]**2:.2f} \n\
MAE: {mean_absolute_error(labels_train_folds[e,:,fold], pred_train_folds[e,:,fold]):.2f} \n\
RMSE: {sqrt(mean_squared_error(labels_train_folds[e,:,fold], pred_train_folds[e,:,fold])):.2f}', color = 'b')

plt.text(4.2, 2.8, f'$R^2$: {pearsonr(labels_test_folds[e,:,fold], pred_test_folds[e,:,fold])[0]**2:.2f} \n\
MAE: {mean_absolute_error(labels_test_folds[e,:,fold], pred_test_folds[e,:,fold]):.2f} \n\
RMSE: {sqrt(mean_squared_error(labels_test_folds[e,:,fold], pred_test_folds[e,:,fold])):.2f}', color = '#e67e00')

plt.show()

# %%
r2_global_test = []
for e in range(len(range(0,epochs,100))):
    r2_test = [pearsonr(labels_test_folds[e,:,f],pred_test_folds[e,:,f])[0]**2 
                  for f in range(len(train_idx))]
    r2_global_test.append(r2_test)
    
mae_global_test = []
for e in range(len(range(0,epochs,100))):
    mae_test = [mean_absolute_error(labels_test_folds[e,:,f],pred_test_folds[e,:,f])
                  for f in range(len(train_idx))]
    mae_global_test.append(mae_test)

rmse_global_test = []
for e in range(len(range(0,epochs,100))):
    rmse_test = [sqrt(mean_squared_error(labels_test_folds[e,:,f],pred_test_folds[e,:,f]))
                  for f in range(len(train_idx))]
    rmse_global_test.append(rmse_test)

# %%
mean_r2_test = []
std_r2_test = []

mean_mae_test = []
std_mae_test = []

mean_rmse_test = []
std_rmse_test = []

for i in range(len(range(0,epochs,100))):

    mean_r2_test.append(np.mean(r2_global_test[i]))
    std_r2_test.append(np.std(r2_global_test[i]))

    mean_mae_test.append(np.mean(mae_global_test[i]))
    std_mae_test.append(np.std(mae_global_test[i]))

    mean_rmse_test.append(np.mean(rmse_global_test[i]))
    std_rmse_test.append(np.std(rmse_global_test[i]))

# %%
print(f'e value for best R2: {mean_r2_test.index(max(mean_r2_test))}')
print(f'e value for best MAE: {mean_mae_test.index(min(mean_mae_test))}')
print(f'e value for best RMSE: {mean_rmse_test.index(min(mean_rmse_test))}')
# Out:
# e value for best R2: 3
# e value for best MAE: 6
# e value for best RMSE: 3

# %%
e = 6
plt.plot(figsize =(6, 4))
plt.plot(range(len(train_idx)), r2_global_test[e], 'o-', label = '$R^2$', color = 'navy')
plt.plot(range(len(train_idx)), mae_global_test[e], 'v-', label = '$MAE$', color = 'darkorange')
plt.plot(range(len(train_idx)), rmse_global_test[e], 's-', label = 'RMSE', color = 'darkgreen')
plt.xticks(range(len(train_idx)), range(5))

plt.xlabel('Fold', fontweight ='bold', fontsize = 15)
plt.ylabel('Metric value', fontweight ='bold', fontsize = 15)
plt.legend()
plt.show()

# %%
Metrics = ['$R^2$', '$MAE$', '$RMSE$']
x_pos = np.arange(len(Metrics))
CTEs = [mean_r2_test[e], mean_mae_test[e], mean_rmse_test[e]]
error = [std_r2_test[e], std_mae_test[e], std_rmse_test[e]]
CTEs = [round(m,3) for m in CTEs]

# %%
fig, ax = plt.subplots(figsize =(6, 4))
bars = ax.bar(x_pos, CTEs, yerr=error, align='center', color = 'navy', alpha=.5, ecolor='black', capsize=10)
ax.set_ylabel('Value', fontweight ='bold', fontsize = 12)
ax.bar_label(bars)
ax.set_xticks(x_pos)
ax.set_xticklabels(Metrics, fontweight ='bold' ,fontsize = 10)
ax.yaxis.grid(False)

plt.tight_layout()
plt.show()

# %%
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(6, 4))
 
# set height of bar
R2 = mean_r2_test
MAE = mean_mae_test
RMSE = mean_rmse_test
 
# Set position of bar on X axis
br1 = np.arange(len(R2))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, R2, color ='navy', width = barWidth,
        edgecolor ='white', label ='$R^2$')
plt.bar(br2, MAE, color ='darkorange', width = barWidth,
        edgecolor ='white', label ='$MAE$')
plt.bar(br3, RMSE, color ='darkgreen', width = barWidth,
        edgecolor ='white', label ='$RMSE$')
 
# Adding Xticks
plt.xlabel('e value', fontweight ='bold', fontsize = 15)
plt.ylabel('Metric value', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(R2))],
        [i for i in range(len(R2))])
 
plt.legend()
plt.show()

# %%
best_r2 = r2_global_test[e]
best_mae = mae_global_test[e]
best_rmse = rmse_global_test[e]

# %%
df = pd.DataFrame(list(zip(best_r2, best_mae, best_rmse)), columns = ['R2', 'MAE', 'RMSE'])
max = pd.DataFrame(np.transpose(np.array(df.max()))).T
max.columns = df.columns
max = max.rename(index={0:'Max'})
min = pd.DataFrame(np.transpose(np.array(df.min()))).T
min.columns = df.columns
min = min.rename(index={0:'Min'})
mean = pd.DataFrame(np.transpose(np.array(df.mean()))).T
mean.columns = df.columns
mean = mean.rename(index={0:'Mean'})
df = pd.concat([df,max,min,mean], axis = 0)
df.index.name = 'fold'
df
# Out:
#             R2       MAE      RMSE
# fold
# 0     0.559243  0.259211  0.341175
# 1     0.370491  0.355081  0.451838
# 2     0.489058  0.298583  0.357748
# 3     0.673163  0.232344  0.298835
# 4     0.538740  0.263362  0.339205
# Max   0.673163  0.355081  0.451838
# Min   0.370491  0.232344  0.298835
# Mean  0.526139  0.281716  0.357760
